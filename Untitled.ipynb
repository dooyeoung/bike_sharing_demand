# %%
# %matplotlib inline
plt.style.use('ggplot')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
sub = pd.read_csv('data/sampleSubmission.csv')

# %%
train.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
test.tail()
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981

# %%
train.shape, test.shape
# Out:
# ((10886, 12), (6493, 9))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
train.isna().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %% [markdown]
# nan 데이터는 없다

# %%
import missingno as msno

# %%
msno.matrix(train, figsize=(12, 3))
plt.show()

# %% [markdown]
# ### 시간 데이터 추가

# %%
train["datetime"] = pd.to_datetime(train["datetime"])
train["year"] = train["datetime"].dt.year
train["month"] = train["datetime"].dt.month
train["day"] = train["datetime"].dt.day
train["hour"] = train["datetime"].dt.hour
train["minute"] = train["datetime"].dt.minute
train["second"] = train["datetime"].dt.second
train["weekday"] = train["datetime"].dt.weekday

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  weekday
# 0       0       0        5
# ...

# %%
plt.figure(figsize=(15, 15))
for idx, col in enumerate(['year','weekday', 'month', 'day', 'hour', 'minute', 'second', 'season', 'holiday', 'workingday', 'weather']):
    plt.subplot(4, 3, idx+1)
    sns.barplot(train[col], train['count'])
    plt.title(col)
plt.tight_layout(pad=1, h_pad=1)
plt.show()

# %% [markdown]
# - year : 2011년보다 2012년이 더 많음
# - weekday : 매일 비슷하다
# - month : 6월이 가장 많고, 봄부터 가을까지 판매량이 증가 추세이다
# - day : 19일까지만 데이터가 존재하기에 데이터분석시 제외되어야 한다
# - hour : 출퇴근 시간에 대영량이 많다
# - minute, seconde : 모두 0이기에 데이터분석시 제외되어야 한다
# - season : 여름, 가을에 대여량이 많다
# - holiday : 주중, 주말 대여량은 비슷하다
# - workingday : 공휴일과 평일의 대여량은 비슷하다
# - weather : 1, 2 대여량이 많음
#
#     > 1: Clear, Few clouds, Partly cloudy, Partly cloudy<br>
#     2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist <br>
#     3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds <br>
#     4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog

# %%
plt.figure(figsize=(15, 15))
for idx, col in enumerate(['year', 'weekday', 'month', 'day', 'hour', 'season', 'holiday', 'workingday', 'weather']):
    plt.subplot(4, 3, idx+1)
    sns.boxplot(train[col], train['count'])
    plt.title(col)

plt.subplot(4, 3, 10)
sns.boxplot(train['count'], orient='v')
plt.title('count')

plt.tight_layout(pad=1, h_pad=1)
plt.show()

# %% [markdown]
# - 아웃라이어 제거가 필요하다

# %%
plt.figure(figsize=(15, 3))
sns.pointplot(data=train, x='hour', y='count')
plt.show()

plt.figure(figsize=(15, 15))
for idx, col in enumerate(['workingday','weekday','weather','season']):
    ax = plt.subplot(4, 1, idx+1)
    sns.pointplot(data=train, x='hour', y='count', hue=col, ax=ax)
plt.tigh_layout(h_pad=1)
plt.show()

# %% [markdown]
# - 전체적인 대여량은 출퇴근시간에 많이 분포되어있다
# - 공유일과 평일의 데이터를 보면 출퇴근시간과, 평일시간으로 나뉜다.
# - 주중, 주말도 마찬가지로 춮퇴근시관과, 평일시간으로 나뉜다.
# - 날씨는 추세의 영향을 미치치 않지만 4번 날씨는 문제가 있어보인다
# - 계절 또한 추세의 영향을 미치치 않는다

# %% [markdown]
# ### 상관관계 파악

# %%
col_num = ['temp','atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count']

# %%
corr = train[col_num].corr()
# 필요한 부분만 출력하기
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False

# %%
corr
# Out:
#                 temp     atemp  humidity  windspeed    casual  registered  \
# temp        1.000000  0.984948 -0.064949  -0.017852  0.467097    0.318571
# atemp       0.984948  1.000000 -0.043536  -0.057473  0.462067    0.314635
# humidity   -0.064949 -0.043536  1.000000  -0.318607 -0.348187   -0.265458
# windspeed  -0.017852 -0.057473 -0.318607   1.000000  0.092276    0.091052
# casual      0.467097  0.462067 -0.348187   0.092276  1.000000    0.497250
# registered  0.318571  0.314635 -0.265458   0.091052  0.497250    1.000000
# count       0.394454  0.389784 -0.317371   0.101369  0.690414    0.970948
#
#                count
# temp        0.394454
# atemp       0.389784
# humidity   -0.317371
# windspeed   0.101369
# casual      0.690414
# registered  0.970948
# count       1.000000

# %%
plt.figure(figsize=(7, 7))
sns.heatmap(corr, square=True, annot=True, mask=mask)
plt.show()

# %%
plt.figure(figsize=(15, 10))
for idx, col in enumerate(['temp','atemp', 'humidity', 'windspeed', 'casual', 'registered']):
    plt.subplot(3, 2, idx+1)
    sns.regplot(data=train, x=col, y='count')
plt.tight_layout(pad=1, h_pad=1)
plt.show()

# %% [markdown]
# - 온도, 체감온도 습도, 풍속은 대여량과 연관관계가 적다
# - 대여량은 등록된 대여자가 상관관계가 높지만 test에는 이 변수가 없다
# - 온도와 체감온도는 상관관계가 높으으로 둘중 하나만 독립변수로 사용여야 한다
# - 풍속에 0수치는 측정되지 않은 값으로 생각된다

# %% [markdown]
# ### 2011, 2012데이터 비교

# %%
t_2011 = train[train['year']==2011]
t_2012 = train[train['year']==2012]

# %%
plt.figure(figsize=(15, 5))
sns.pointplot(data=t_2011, x='month', y='count')
sns.pointplot(data=t_2012, x='month', y='count')
plt.show()

# %% [markdown]
# ### UCL, LCL 파악

# %% [markdown]
# 관리도의 기본개념
#
# 관리도는 관리상한선(UCL: Upper Control Limit)과 관리하한선(LCL: Lower Control Limit)을 설정하고, 이를 프로세스 관리에 이용하기 위한 일종의 꺾은선 그래프이다. 관리도를 사용하면 프로세스가 관리상태에 있는지 아닌지를 신속하게 판정할 수 있다.
#
# UCL = 평균 + 3 x 표준편차 <br>
# LCL = 평균 - 3 x 표준편차 입니다.

# %% [markdown]
# ![caption](img/1.png)

# %%
ucl = np.mean(train['count']) + (3 * np.std(train['count']))
lcl = np.mean(train['count']) - (3 * np.std(train['count']))

# %%
plt.figure(figsize=(15, 5))
plt.plot(train['count'])
plt.plot([ucl] * len(train))
plt.plot([lcl] * len(train))
plt.show()

# %% [markdown]
# - ucl 기준에 넘어서는 데이터들이 존재한다

# %%
plt.figure(figsize=(15, 5))
ax = plt.subplot(121)
sns.distplot(train['count'], ax = ax)
ax = plt.subplot(122)
sp.stats.probplot(train["count"], dist='norm', fit=True, plot=ax)
plt.tight_layout(pad=1)
plt.show()

# %% [markdown]
# - 정규분포를 따르지 않는다

# %%
train['logcount'] = np.log1p(train['count'])

# %%
plt.figure(figsize=(15, 5))
ax = plt.subplot(121)
sns.distplot(train['logcount'], ax = ax)
ax = plt.subplot(122)
sp.stats.probplot(train["logcount"], dist='norm', fit=True, plot=ax)
 
plt.tight_layout(pad=1)
plt.show()

# %% [markdown]
# - 로그를 취해도 정규분포를 따르지 않는다
